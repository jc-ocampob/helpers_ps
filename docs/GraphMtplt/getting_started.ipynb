# %% [markdown]
# # Getting Started
#
# `GraphMtplt` is the main class that handles the creation of institutional type graphs with standarized formating and ample flexibility
#
# -----
# ## Importing and creating an instance
#
# Creating an instance of the class takes 1 positional argument `dataframe` that is later used in graph creation. Te positional argument can take in a single `pd.Dataframe` or a list of `pd.Dataframe`.

# %%
import helpers_ps as hp

g = hp.GraphMtplt(dataframe = df | [df_1, df_2,...])

# %% [markdown]
# ---
# ## Plotting
#
# | Method | Description |
# |---|---|
# | [`plot()`](../plotting) | Figure generation |
# | [`axis()`](../plotting) | Multiplot axis selection |
# | [`subplot_adjust()`](../plotting) | Adjust Figure level position and size |

# %% [markdown]
# ---
# ## Figure level layout components
#
# | Method | Description |
# |---|---|
# | [`add_title()`](../layout) | Adds figure level title |
# | [`subtitle()`](../layout)  | Adds figure level subtitle |
# | [`add_source()`](../layout)  | Adds figure level source |
# | [`add_plot_title()`](../layout)  | Adds plot level title |

# %% [markdown]
# ---
# ## Available graph types
#
# | Method | Description |
# |---|---|
# | [`graph_line()`](../Line/graph) | Time series and indicator evolution |
# | [`graph_bar()`](../Bar/graph) | Bars (simple, stacked, grouped) |
# | [`graph_pie()`](../Pie/graph) | Pie y Donut charts |
# | [`graph_box_whiskers()`](../Box/graph) | Historical distribution by series |

# %% [markdown]
# ---
# ## Next Step
#
# [Graph Plotting ->](../plotting)
