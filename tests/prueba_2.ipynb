# %%
import sys
import os

sys.path.append(
    os.path.abspath("..")
)
import helpers_ps as hp
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(
    {
        "Portfolio": [100, -102, -105, 103, 108],
        "Benchmark": [100, 101, 103, 104, 106],
    },
    index=pd.date_range("2024-01-31", periods=5, freq="ME")
)

hp.set_graph_theme()

g = hp.GraphMtplt(dataframe=df)

g = (
    g
    .plot(ncols=2, width_ratios=[0.3, 0.3], wspace=0.4)
    .add_title("Portafolio vs Benchmark")
    .add_subtitle("Rendimiento promedio ult.12 meses")
    .add_source(["Fuente: Credicorp Capital"])
    .graph_line(
        series = [{
            "ticker":"Portfolio",
            "axis_side":"left",
            "lw": 1,
            "linestyle":"--",
            "tags":[{
                "x_values": "last",
                "template": "{y_value:,.0f}",
                "tag":{
                    "bg_alpha":1,
                    "show_bbox": True,
                    "bg_color":"red"
                },
            }]
        }]
    )
    .graph_line(
        series = [{"ticker":"Benchmark", "axis_side":"right"}]
    )
    .tag(pd.to_datetime("2024-03-31"), y_value=105, label="hol")
    .add_legend()
    .add_plot_title("Rendimiento de benchmark")
    .axis(1)
    .graph_line(
        series = [{"ticker":"Benchmark"}],
        x_axis=dict(
            bbg_format=True,
             tick_step=2
        )
    )
    .config_yaxis(
        label="NAV",
        label_color="red",
        spine_color="black",
        fmt=",.0%"
    )
    .add_plot_title(
        "Rendimiento del portafolio",
        loc="left",
        fontweight="normal",
        color="red",
        fontstyle="oblique",
        y=1.01
    )

    
    
)

# %%
df2 = pd.DataFrame(
    {
        "Activo": ["Renta Fija", "Renta Variable", "Alternativos"],
        "Benchmark": [0.2, 0.5, 0.3],
    },
).set_index("Activo")

display(df2)

hp.set_graph_theme()

g = hp.GraphMtplt(dataframe=[df2, df])

g = (
    g
    .plot(ncols=2)
    .add_title("Portafolio vs Benchmark")
    .add_subtitle("Rendimiento promedio ult.12 meses")
    .add_source(["Fuente: Credicorp Capital"])
    .graph_bar(
        series=[{
            "ticker":"Benchmark"
        }],
    )
    .axis(1)
    .graph_bar(
        df_index=1,
        series=[
            {
                "ticker":"Portfolio",
                "tag":[{
                    "x_values":"all",
                    "template":"{y_value:,.0f}",
                    "color":"white",
                    "fontweight":"bold"
                }]
            },
            {
                "ticker":"Benchmark",
                "tag":[{
                    "x_values":"all",
                    "template":"{y_value:,.0f}",
                    "color":"white",
                    "fontweight":"bold"
                }]
            }
        ],
        stacked=True,
        x_axis=dict(
            fmt="%b",
            tick_step=1
        )
    )
)
# Out:
#                 Benchmark
# Activo
# Renta Fija            0.2
# Renta Variable        0.5
# Alternativos          0.3

# %%
df_stacked = pd.DataFrame(
    {
        "Renta Fija": [40, 45, 42, 48, 50],
        "Renta Variable": [35, 32, 38, 34, 36],
        "Alternativos": [15, 18, 16, 20, 19],
    },
    index=pd.to_datetime(
        [
            "2026-02-28",
            "2026-03-31",
            "2026-04-30",
            "2026-05-31",
            "2026-06-30",
        ]
    ),
)

g = hp.GraphMtplt(
    dataframe=[df_stacked]
)

g = (
    g
    .plot()
    .add_title("Distribución del portafolio")
    .add_subtitle("Asignación por clase de activo")
    .add_source(["Fuente: Credicorp Capital"])
    .graph_bar(
        stacked=True,
        series=[
            {
                "ticker": "Renta Fija",
                "label": "Renta Fija",
                "color": "#15192C",
                "tag": [
                    {
                        "show": "stack_total",
                        "x_values": "all",
                        "template": "{total_value:,.1f}",
                        "fontsize": 8,
                        "fontweight": "bold",
                        "color": "#262626",
                        "ubic_etq": (0, 5),
                    },
                    {
                        "x_values": "all",
                        "template": "{y_value:,.1f}",
                        "fontsize": 8,
                        "fontweight": "bold",
                        "color": "white",
                        "ubic_etq": (0, 5),
                    }
                ],
            },
            {
                "ticker": "Renta Variable",
                "label": "Renta Variable",
                "color": "#5170A3",
            },
            {
                "ticker": "Alternativos",
                "label": "Alternativos",
                "color": "#A6B7D4",
            },
        ],
        x_axis={
            "fmt": "%b.",
            "tick_step": 1,
        },
    )
    .add_legend()
)

# %%
df_pie = pd.DataFrame(
    {
        "Portfolio": [
            0.45,
            0.30,
            0.15,
            0.10,
        ],
    },
    index=[
        "Renta Fija",
        "Renta Variable",
        "Alternativos",
        "Liquidez",
    ],
)

display(df_pie)
# Out:
#                 Portfolio
# Renta Fija           0.45
# Renta Variable       0.30
# Alternativos         0.15
# Liquidez             0.10

# %%
hp.set_graph_theme()

g = hp.GraphMtplt(
    dataframe=[df_pie]
)

g = (
    g
    .plot()
    .add_title(
        "Distribución del portafolio"
    )
    .add_subtitle(
        "Asignación estratégica por clase de activo"
    )
    .add_source(
        ["Fuente: Credicorp Capital"]
    )
    .graph_pie(
        ticker="Portfolio",
        autopct="%1.1f%%",
    )
)

# %%
hp.set_graph_theme()

g = hp.GraphMtplt(
    dataframe=[df_pie]
)

g = (
    g
    .plot()
    .add_title(
        "Distribución del portafolio"
    )
    .add_subtitle(
        "Asignación estratégica por clase de activo"
    )
    .add_source(
        ["Fuente: Credicorp Capital"]
    )
    .graph_pie(
        ticker="Portfolio",
        colors={
            "Renta Fija": "#15192C",
            "Renta Variable": "#5170A3",
            "Alternativos": "#A6B7D4",
            "Liquidez": "#D8DEE9",
        },
        donut_width=0.45,
        startangle=90,
        counterclock=False,
        autopct="%1.1f%%",
        pctdistance=0.76,
        labeldistance=1.08,
        label_color="#262626",
        autopct_color="white",
        autopct_fontweight="bold",
        wedgeprops={
            "edgecolor": "white",
            "linewidth": 1.5,
        },
    )
    .subplot_adjust(bottom=0.15)
)

# %%
hp.set_graph_theme()

g = hp.GraphMtplt(
    dataframe=[df_pie]
)

g = (
    g
    .plot()
    .add_title(
        "Distribución del portafolio"
    )
    .add_subtitle(
        "Liquidez destacada"
    )
    .add_source(
        ["Fuente: Credicorp Capital"]
    )
    .graph_pie(
        ticker="Portfolio",
        colors={
            "Renta Fija": "#15192C",
            "Renta Variable": "#5170A3",
            "Alternativos": "#A6B7D4",
            "Liquidez": "#D8DEE9",
        },
        explode={
            "Liquidez": 0.10,
        },
        donut_width=0.45,
        sort_values=True,
        autopct="%1.1f%%",
        wedgeprops={
            "edgecolor": "white",
            "linewidth": 1.5,
        },
    )
)

# %%
rng = np.random.default_rng(42)

df_box = pd.DataFrame(
    {
        "Portfolio": rng.normal(
            loc=0.008,
            scale=0.025,
            size=60,
        ),
        "Benchmark": rng.normal(
            loc=0.006,
            scale=0.020,
            size=60,
        ),
        "Peer Group": rng.normal(
            loc=0.005,
            scale=0.030,
            size=60,
        ),
    }
)

display(df_box.head())
# Out:
#    Portfolio  Benchmark  Peer Group
# 0   0.015618  -0.027657   -0.025705
# 1  -0.018000  -0.000698    0.010378
# 2   0.026761   0.009255    0.011600
# 3   0.031514   0.017724    0.045776
# 4  -0.040776   0.020225    0.030053

# %%
hp.set_graph_theme()

g = hp.GraphMtplt(
    dataframe=[df_box]
)

g = (
    g
    .plot()
    .add_title(
        "Distribución de retornos"
    )
    .add_subtitle(
        "Retornos mensuales por estrategia"
    )
    .add_source(
        ["Fuente: Datos de prueba"]
    )
    .graph_box_whiskers(
        series=[
            {
                "ticker": "Portfolio",
                "label": "Portafolio",
                "color": "#15192C",
            },
            {
                "ticker": "Benchmark",
                "label": "Benchmark",
                "color": "#5170A3",
            },
            {
                "ticker": "Peer Group",
                "label": "Peer Group",
                "color": "#A6B7D4",
            },
        ],
        box_config={
            "whis": (0, 100),
            "showfliers": False,
        },
        x_axis={
            "fontsize": 8,
            "rotation": 0,
            "ha": "center",
            "va": "top",
        },
    )
)

# %%
g = (
    hp.GraphMtplt(
        dataframe=[df_box]
    )
    .plot()
    .add_title(
        "Distribución de retornos"
    )
    .add_subtitle(
        "Retornos mensuales por estrategia"
    )
    .add_source(
        ["Fuente: Datos de prueba"]
    )
    .graph_box_whiskers(
        series=[
            {
                "ticker": "Portfolio",
                "label": "Portafolio",
                "color": "#15192C",
            },
            {
                "ticker": "Benchmark",
                "label": "Benchmark",
                "color": "#5170A3",
            },
            {
                "ticker": "Peer Group",
                "label": "Peer Group",
                "color": "#A6B7D4",
            },
        ],
    )
    .add_legend()
)

# %%
# ---------------------------------------------------------
# 1. Create daily P/E data for three stocks
# ---------------------------------------------------------
rng = np.random.default_rng(42)

dates = pd.bdate_range(
    start="2025-01-01",
    end="2026-09-04",
)

df_pe = pd.DataFrame(
    {
        "AAPL": rng.normal(
            loc=29.0,
            scale=2.5,
            size=len(dates),
        ),
        "MSFT": rng.normal(
            loc=34.0,
            scale=3.0,
            size=len(dates),
        ),
        "GOOGL": rng.normal(
            loc=24.0,
            scale=2.0,
            size=len(dates),
        ),
    },
    index=dates,
)

df_pe.index.name = "Date"

display(df_pe.tail())
# Out:
#                  AAPL       MSFT      GOOGL
# Date
# 2026-08-31  24.422735  30.976321  23.304953
# 2026-09-01  31.320742  36.172848  21.639998
# 2026-09-02  27.487498  34.189007  25.609141
# 2026-09-03  27.665249  28.324161  22.649772
# 2026-09-04  26.325619  28.124226  24.807908

# %%
last_date = df_pe.index.max()

previous_month = (
    last_date.to_period("M") - 1
)

previous_month_close = (
    df_pe.loc[
        df_pe.index.to_period("M")
        == previous_month
    ]
    .index
    .max()
)

# %%
g = (
    hp.GraphMtplt(
        dataframe=[df_pe]
    )
    .plot()
    .add_title(
        "Price-to-Earnings Distribution"
    )
    .add_subtitle(
        "Historical P/E range and selected observations"
    )
    .add_source(
        ["Source: Synthetic data"]
    )
    .graph_box_whiskers(
        series=[
            {
                "ticker": "AAPL",
                "label": "Apple",
                "color": "#15192C",
                "tag": [
                    # Top of the distribution
                    {
                        "mode": "statistic",
                        "statistic": "high",
                        "tag": {
                            "label": "{y_value:.1f}x",
                            "fontsize": 8,
                            "fontweight": "bold",
                            "font_color": "#262626",
                            "ubic_etq": (0, 6),
                            "label_h_align": "center",
                            "label_v_align": "bottom",
                            "show_bbox": False,
                        },
                        "dot": None,
                    },

                    # Bottom of the distribution
                    {
                        "mode": "statistic",
                        "statistic": "low",
                        "tag": {
                            "label": "{y_value:.1f}x",
                            "fontsize": 8,
                            "fontweight": "bold",
                            "font_color": "#262626",
                            "ubic_etq": (0, -6),
                            "label_h_align": "center",
                            "label_v_align": "top",
                            "show_bbox": False,
                        },
                        "dot": None,
                    },

                    # Latest observation
                    {
                        "mode": "observation",
                        "x_values": "last",
                        "tag": {
                            "label": (
                                "{y_value:.1f}x"
                            ),
                            "fontsize": 8,
                            "fontweight": "bold",
                            "font_color": "#C53B3B",
                            "ubic_etq": (7, 6),
                            "label_h_align": "left",
                            "label_v_align": "bottom",
                            "bg_color": "white",
                            "bg_alpha": 0.90,
                            "edge_color": "None",
                            "show_bbox": True,
                            "zorder": 25,
                        },
                        "dot": {
                            "marker": "o",
                            "markersize": 5,
                            "marker_color": "#C53B3B",
                            "marker_edgecolor": "white",
                            "marker_edgewidth": 0.7,
                            "alpha": 1.0,
                            "zorder": 24,
                            "label":"Last"
                        },
                    },

                    # Previous month close
                    {
                        "mode": "observation",
                        "x_values": [
                            previous_month_close
                        ],
                        "tag": {
                            "label": (
                                "{y_value:.1f}x"
                            ),
                            "fontsize": 8,
                            "fontweight": "bold",
                            "font_color": "#9A6810",
                            "ubic_etq": (7, -6),
                            "label_h_align": "left",
                            "label_v_align": "top",
                            "bg_color": "white",
                            "bg_alpha": 0.90,
                            "edge_color": "None",
                            "show_bbox": True,
                            "zorder": 25,
                        },
                        "dot": {
                            "marker": "D",
                            "markersize": 5,
                            "marker_color": "#E0A228",
                            "marker_edgecolor": "white",
                            "marker_edgewidth": 0.7,
                            "alpha": 1.0,
                            "zorder": 24,
                            "label":"Previous month"
                        },
                    },
                ],
            },

            {
                "ticker": "MSFT",
                "label": "Microsoft",
                "color": "#5170A3",
                "tag": [
                    # Top of the distribution
                    {
                        "mode": "statistic",
                        "statistic": "high",
                        "tag": {
                            "label": "{y_value:.1f}x",
                            "fontsize": 8,
                            "fontweight": "bold",
                            "font_color": "#262626",
                            "ubic_etq": (0, 6),
                            "label_h_align": "center",
                            "label_v_align": "bottom",
                            "show_bbox": False,
                        },
                        "dot": None,
                    },

                    # Bottom of the distribution
                    {
                        "mode": "statistic",
                        "statistic": "low",
                        "tag": {
                            "label": "{y_value:.1f}x",
                            "fontsize": 8,
                            "fontweight": "bold",
                            "font_color": "#262626",
                            "ubic_etq": (0, -6),
                            "label_h_align": "center",
                            "label_v_align": "top",
                            "show_bbox": False,
                        },
                        "dot": None,
                    },

                    # Latest observation
                    {
                        "mode": "observation",
                        "x_values": "last",
                        "tag": {
                            "label": (
                                "{y_value:.1f}x"
                            ),
                            "fontsize": 8,
                            "fontweight": "bold",
                            "font_color": "#C53B3B",
                            "ubic_etq": (7, 6),
                            "label_h_align": "left",
                            "label_v_align": "bottom",
                            "bg_color": "white",
                            "bg_alpha": 0.90,
                            "edge_color": "None",
                            "show_bbox": True,
                            "zorder": 25,
                        },
                        "dot": {
                            "marker": "o",
                            "markersize": 5,
                            "marker_color": "#C53B3B",
                            "marker_edgecolor": "white",
                            "marker_edgewidth": 0.7,
                            "alpha": 1.0,
                            "zorder": 24,
                            "label":"Last"
                        },
                    },

                    # Previous month close
                    {
                        "mode": "observation",
                        "x_values": [
                            previous_month_close
                        ],
                        "tag": {
                            "label": (
                                "{y_value:.1f}x"
                            ),
                            "fontsize": 8,
                            "fontweight": "bold",
                            "font_color": "#9A6810",
                            "ubic_etq": (7, -6),
                            "label_h_align": "left",
                            "label_v_align": "top",
                            "bg_color": "white",
                            "bg_alpha": 0.90,
                            "edge_color": "None",
                            "show_bbox": True,
                            "zorder": 25,
                        },
                        "dot": {
                            "marker": "D",
                            "markersize": 5,
                            "marker_color": "#E0A228",
                            "marker_edgecolor": "white",
                            "marker_edgewidth": 0.7,
                            "alpha": 1.0,
                            "zorder": 24,
                            "label":"Previous month"
                        },
                    },
                ],
            },

            {
                "ticker": "GOOGL",
                "label": "Alphabet",
                "color": "#A6B7D4",
                "tag": [
                    # Top of the distribution
                    {
                        "mode": "statistic",
                        "statistic": "high",
                        "tag": {
                            "label": "{y_value:.1f}x",
                            "fontsize": 8,
                            "fontweight": "bold",
                            "font_color": "#262626",
                            "ubic_etq": (0, 6),
                            "label_h_align": "center",
                            "label_v_align": "bottom",
                            "show_bbox": False,
                        },
                        "dot": None,
                    },

                    # Bottom of the distribution
                    {
                        "mode": "statistic",
                        "statistic": "low",
                        "tag": {
                            "label": "{y_value:.1f}x",
                            "fontsize": 8,
                            "fontweight": "bold",
                            "font_color": "#262626",
                            "ubic_etq": (0, -6),
                            "label_h_align": "center",
                            "label_v_align": "top",
                            "show_bbox": False,
                        },
                        "dot": None,
                    },

                    # Latest observation
                    {
                        "mode": "observation",
                        "x_values": "last",
                        "tag": {
                            "label": (
                                "{y_value:.1f}x"
                            ),
                            "fontsize": 8,
                            "fontweight": "bold",
                            "font_color": "#C53B3B",
                            "ubic_etq": (7, 6),
                            "label_h_align": "left",
                            "label_v_align": "bottom",
                            "bg_color": "white",
                            "bg_alpha": 0.90,
                            "edge_color": "None",
                            "show_bbox": True,
                            "zorder": 25,
                        },
                        "dot": {
                            "marker": "o",
                            "markersize": 5,
                            "marker_color": "#C53B3B",
                            "marker_edgecolor": "white",
                            "marker_edgewidth": 0.7,
                            "alpha": 1.0,
                            "zorder": 24,
                            "label": "Last"
                        },
                    },

                    # Previous month close
                    {
                        "mode": "observation",
                        "x_values": [
                            previous_month_close
                        ],
                        "tag": {
                            "label": (
                                "{y_value:.1f}x"
                            ),
                            "fontsize": 8,
                            "fontweight": "bold",
                            "font_color": "#9A6810",
                            "ubic_etq": (7, -6),
                            "label_h_align": "left",
                            "label_v_align": "top",
                            "bg_color": "white",
                            "bg_alpha": 0.90,
                            "edge_color": "None",
                            "show_bbox": True,
                            "zorder": 25,
                        },
                        "dot": {
                            "marker": "D",
                            "markersize": 5,
                            "marker_color": "#E0A228",
                            "marker_edgecolor": "white",
                            "marker_edgewidth": 0.7,
                            "alpha": 1.0,
                            "zorder": 24,
                            "label":"Previous month"
                        },
                    },
                ],
            },
        ],
        box_config={
            "whis": (0, 100),
            "showfliers": False,
            "widths": 0.60,
        },
        box_face_alpha=0.55,
        x_axis={
            "fontsize": 8,
            "rotation": 0,
            "ha": "center",
            "va": "top",
        },
    )
    .config_yaxis(
        fmt=",.1f",
        side="left",
        lim=(0, 55),
    )
    .horizontal_guides(
        mostrar_cero=False,
    )
    .add_legend(legend_mode="points")
)
