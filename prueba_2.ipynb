# %%
import helpers_ps as hp
import pandas as pd

# %%
df = pd.DataFrame(
    {
        "Portfolio": [100, 102, 105, 103, 108],
        "Benchmark": [100, 101, 103, 104, 106],
    },
    index=pd.date_range("2024-01-31", periods=5, freq="ME")
)

hp.set_graph_theme()

g = hp.GraphMtplt(dataframe=df)

g.graph_line(
    tickers="all",
    titles={
        "title": "Portfolio vs Benchmark"
    }
)
g.add_source(["Fuente: Credicorp Capital"])
g.tag(pd.to_datetime("2024-03-31"), y_value=105, label="hol")
# Out:
# GraphMtplt()

# %%
df = pd.DataFrame(
    {
        "Portfolio": [100, 102, 105, 103, 108],
        "Benchmark": [100, 101, 103, 104, 106],
    },
    index=pd.date_range("2024-01-31", periods=5, freq="ME")
)

hp.set_graph_theme()

g = (
    hp.GraphMtplt(dataframe=df)
    .graph_line(
        tickers="Portfolio",
        titles={
            "title": "Portfolio vs Benchmark"
        },
        axis_side="left"
    )
    .add_source(["Fuente: Credicorp Capital"])
    .tag(pd.to_datetime("2024-03-31"), y_value=105, label="hol")
    .shade_x([("2023-12-31", "2024-03-31")])
    .graph_bar(
        tickers="Benchmark",
        axis_side="right",
    )
)

# %%
hp.Powerpoint.Line_chart

# %%
import pandas as pd
# Optional: apply default chart style
set_graph_theme()

# Example dataframe
df = pd.DataFrame(
    {
        "Portfolio": [100, 102, 105, 103, 108],
        "Benchmark": [100, 101, 103, 104, 106],
    },
    index=pd.date_range("2024-01-31", periods=5, freq="ME")
)

# Create graph object
g = GraphMtplt(dataframe=df)

# Create line chart
g.graph_line(
    tickers=["Portfolio", "Benchmark"],
    labels=["Portfolio", "Benchmark"],
    titles={
        "title": "Portfolio vs Benchmark",
        "subtitle": "Indexed performance"
    },
    source={
        "source": "Source: Internal calculations"
    },
    legend={
        "show": True
    }
)

# Save to memory buffer
g.save(name="portfolio_vs_benchmark")

# Access image buffer
img = buffers["portfolio_vs_benchmark"]
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 2
#       1 import pandas as pd
# ----> 2 from helpers_ps.MtpltGraph import GraphMtplt, set_graph_theme, buffers
#       3
#       4 # Optional: apply default chart style
#       5 set_graph_theme()
#
# ImportError: cannot import name 'buffers' from 'helpers_ps.MtpltGraph' (d:\Datos de Usuarios\K02066\Desktop\Helpers_PS\helpers_ps\helpers_ps\MtpltGraph\__init__.py)

# %%
hp.FinCalculations
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 hp.Presentacion
#
# AttributeError: module 'helpers_ps' has no attribute 'Presentacion'
